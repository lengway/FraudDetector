# %% [markdown]
# realtime_fraud_protection

# %% [markdown]
# amount
# time_of_day
# device_id
# user_id
# user_avg_amount_30d
# user_tx_count_24h
# geo_distance_last_tx
# is_new_device
# merchant_category
# unusual_amount_flag
