# %% [markdown]
# Признак	                    | Баллы
# rare_os_flag = 1            | +2
# suspicious_device_combo = 1	| +2
# rare_device_flag = 1	    | +2
# volatility_index высокое	| +1
# много смен модели	        | +1
